# %% [markdown]
# <a href="https://colab.research.google.com/github/Abrar-404/AI-ML_Practices_and_Assignments/blob/main/Module_03_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## What is a decision boundary, and how does it relate to classification tasks?
# - A decision boundary is a line that separates or classifies the data into different classes in a classification problem. The decision boundary first classifies the data in separate groups for example cats / dogs and then label the data. The model learns these boundary during training using these labels and predicts through these patterns for new, unseen data
#
# ## How does the bias term in a neuron affect the position of the decision boundary?
# - The bias shifts the decision boundary without changing its slope/orientation. Weights determine the boundary's direction, while the bias determines its offset from the origin, together they let the boundary be positioned correctly to separate the classes.
#
# ## Explain with an example how changing weights affects the orientation of the decision boundary.
#
# - The weights are the value that determines the boundary direction. For example: Z = x1w1 + x2w2 + b = 0. Here if w1 = 1, w2 = 1 then the line would be a perfect 45 degree angle. if I increase the w1 = 2 then the line would be shift a little steeper.
#
# ## Why is it important to visualize the decision boundary when training a model?
# - Because without visualizing we can't measure the changes properly. As it is a supervised learning method, we need to tune the hyperparametes so visualizing helps us to update the weights, bias for fit the model in the best manner to get an accuate output. It also helps to see if the data is linearly separable or not, is the data is underfitting or overfitting, understand the data behavior.

# %% [markdown]
# # Math :

# %% [markdown]
# ## 1. Weight Update (Perceptron Learning Rule)
#
#  A perceptron has:
# Initial weights: w = [0.2, -0.1]
#
#
# Bias: b = 0.1
#
#
# Learning rate: η = 0.1
#
#
# For a training example with:
# x = [1, 1]
#
#
# Target t = 1
#
#
# If the perceptron output is y = 0, calculate the new weights and bias after one update using:
#
# w_new = w + η * (t - y) * x
#
# b_new = b + η * (t - y)

# %% [markdown]
# ## ANS:
#
# - z = x1w1 + x2w2 + b
#   - (1 * 0.2) + (1 * -0.1) + 0.1 = 0.2 > 0 = 1
#
# - w1_new = w + η * (t - y) * x
#   - 0.2 + 0.1 * (1 - 0) * 1 = 0.3
#
# - w2_new = w + η * (t - y) * x
#   - -0.1 + 0.1 * (1 - 0) * 1 = 0
#
# - b_new = b + η * (t - y)
#   - 0.1 + 0.1 * (1 - 0) = 0.2
