# %% [markdown]
# <a href="https://colab.research.google.com/github/Abrar-404/AI-ML_Practices_and_Assignments/blob/main/Module_08_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice docs (the practice was not good. need to learn from conceptual)
#
# Docs:- https://docs.google.com/document/d/14K8JrUSz4_3DmgTAx6YDL-xMkJDWj4P8/edit?usp=sharing&ouid=111838451282323711093&rtpof=true&sd=true

# %%
# !pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 9.8 MB/s eta 0:00:00
# ...

# %%
import docx

# Replace with your actual file name
doc = docx.Document("Backpropagation_Walkthrough.docx")

# %%
for paragraph in doc.paragraphs:
    print(paragraph.text)
# Out:
# Manual Backpropagation Walkthrough
# Architecture: 3 - 4 - 3 - 2 - 1   |   Activation: Linear (o = z)   |   Learning rate η = 0.01
#
#
#
#
# Step 1: Network Architecture
# A fully connected feedforward network with the following layer sizes:
#
#
#
# Input layer: 3 nodes
# Hidden Layer 1: 4 nodes
# Hidden Layer 2: 3 nodes
# Hidden Layer 3: 2 nodes
# Output layer: 1 node
#
# Step 2: Initialize all weights and biases with small numerical values.
# All weights (w) and biases (b) are initialized to a small constant value of 0.1, to keep the manual calculations clean and traceable.
#
# 1. Hidden Layer 1 Parameters
# W1  —  4 × 3 matrix
#
# b1  —  4 × 1 vector
#
# 2. Hidden Layer 2 Parameters
# W2  —  3 × 4 matrix
#
# b2  —  3 × 1 vector
#
# 3. Hidden Layer 3 Parameters
# W3  —  2 × 3 matrix
#
# b3  —  2 × 1 vector
#
# 4. Output Layer Parameters
# W4  —  1 × 2 matrix
#
# b4  —  1 × 1 vector
#
#
# ...
