# %% [markdown]
# <a href="https://colab.research.google.com/github/Abrar-404/AI-ML_Practices_and_Assignments/blob/main/Module_09_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# # You are given:
# - X = torch.tensor([[1.0, 2.0]])
#
# - W = torch.tensor([[0.5], [0.3]])
#
# - b = torch.tensor([[0.1]])
#
#
# ## Questions:
# 1. What are the shapes of X, W, and b? Write code to see shapes.
#
#
# 2. Will torch.matmul(X, W) work? Why?
#
#
# 3. What is the output of  matrix multiplication ? (First write the code by yourself)
#
#
# 4. If it fails, how would you reshape the tensors correctly?
# 5. Manual Forward Pass of a Two-Layer Neural Network

# %%
X = torch.tensor([[1.0, 2.0]])
W = torch.tensor([[0.5],[0.3]])
b = torch.tensor([[0.1]])

# %%
# What are the shapes of X, W, and b? Write code to see shapes.
print('Shape of X:', X.shape)
print('Shape of W:', W.shape)
print('Shape of b:', b.shape)

# Will torch.matmul(X, W) work? Why?
# The matrix multiplication for X and W will work fine because the X has 1, 2 dimention and W has 2, 1 dimention. so it will work just fine

# What is the output of matrix multiplication ? (First write the code by yourself)
matmul = torch.matmul(X, W)
print('Output of matmul:', matmul)

# If it fails, how would you reshape the tensors correctly?
# If it fails I need to transpose the dimention of X to do matrix multiplication correctly with W.

# Manual Forward Pass of a Two-Layer Neural Network
W1, b1 = W, b

z1 = torch.matmul(X, W1) + b1
a1 = torch.sigmoid(z1)

W2 = torch.tensor([[0.07]])
b2 = torch.tensor([[0.02]])

z2 = torch.matmul(a1, W2) + b2
a2 = torch.sigmoid(z2)

print('Layer 1 pre-activation:', z1)
print('Layer 1 output (post-sigmoid):', a1)
print('Layer 2 pre-activation:', z2)
print('Final output (post-sigmoid):', a2)
# Out:
# Shape of X: torch.Size([1, 2])
# Shape of W: torch.Size([2, 1])
# Shape of b: torch.Size([1, 1])
# Output of matmul: tensor([[1.1000]])
# Layer 1 pre-activation: tensor([[1.2000]])
# Layer 1 output (post-sigmoid): tensor([[0.7685]])
# Layer 2 pre-activation: tensor([[0.0738]])
# Final output (post-sigmoid): tensor([[0.5184]])

# %% [markdown]
# # You are given a two-layer neural network with the following parameters:
# - Input X is a column vector of size (2 × 1).
# - W1 is of shape (2 × 2).
# - b1 is of shape (2 × 1).
# - W2 is of shape (2 × 1).
# - b2 is of shape (1 × 1).
#
#
# ## Tasks:
# 1. Write the mathematical formula for Z1.
# 2. Apply ReLU activation to compute A1.
# 3. Write the formula for the final output y_hat.
# 4. If all weights are initialized to 0.1 and biases are zero, compute the final output manually for input X = [[1.0], [2.0]].

# %% [markdown]
# ### 1. Write the mathematical formula for Z1.
# - Ans: Z1 = (W1 * X) + b1
#
# ### 2. Apply ReLU activation to compute A1.
# - Ans: A1 = ReLU(Z1), ReLU zeroes out any negative entries and leaves positive entries unchanged.
#
# ### 3. Write the formula for the final output y_hat.
# - Ans: y_hat = W^T * A1 + b2
#
# ### 4. If all weights are initialized to 0.1 and biases are zero, compute the final output manually for input X = [[1.0], [2.0]].
#
# - Ans:
#
#   - row1 = (0.1 * 1.0) + (0.1 * 2.0) = 0.3 + 0 = 0.3
#   - row2 = (0.1 * 1.0) + (0.1 * 2.0) = 0.3 + 0 = 0.3
#   - z1 = [[0.3], [0.3]]
#   - A1 = ReLU(z1) = [[0.3], [0.3]]
#   - y_hat = W2^T * A1 + b2 = (0.1 * 0.3) + (0.1 * 0.3) = 0.06

# %%
# code to verify

X = torch.tensor([[1.0], [2.0]])
W1 = torch.full((2, 2), 0.1)
b1 = torch.zeros((2, 1))
W2 = torch.full((2, 1), 0.1)
b2 = torch.zeros((1, 1))

z1 = torch.matmul(W1, X) + b1
a1 = torch.relu(z1)
y_hat = torch.matmul(W2.T, a1) + b2

print('Z1:', z1, '\n')
print('A1:', a1, '\n')
print('y_hat:', y_hat)
# Out:
# Z1: tensor([[0.3000],
#         [0.3000]])
#
# A1: tensor([[0.3000],
#         [0.3000]])
#
# y_hat: tensor([[0.0600]])

# %% [markdown]
# # Understanding Mean Squared Error (MSE)
#
# ## Given:
#  - y = 5.0
#  - y_hat = 3.0
#
# ### Questions:
# - Compute the squared error manually.

# %% [markdown]
# ## Compute the squared error manually.
# - Ans: MSE = (1/n) × Σ(yᵢ - ŷᵢ)² = (5.0 - 3.0)^2 = 4
