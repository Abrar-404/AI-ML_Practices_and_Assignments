# %% [markdown]
# <a href="https://colab.research.google.com/github/Abrar-404/AI-ML_Practices_and_Assignments/blob/main/Module_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data.csv')

# %% [markdown]
# # Multivariate Analysis- 1 ( Countplot with Hue-1)

# %%
sns.countplot(x=df['Sex'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender_split = df.groupby('Sex')['Survived'].value_counts(normalize=True)

print(gender_split)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %% [markdown]
# # Multivariate Analysis -1 ( Countplot with Hue-2)

# %%
sns.countplot(x=df['Pclass'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pclass_split = df.groupby('Pclass')['Survived'].value_counts(normalize=True)

print(pclass_split)
# Out:
# Pclass  Survived
# first   yes         0.629630
#         no          0.370370
# second  no          0.527174
#         yes         0.472826
# third   no          0.757637
#         yes         0.242363
# Name: proportion, dtype: float64

# %% [markdown]
# # Multi Variate Analysis -3 ( Barplot for Cat-Num)

# %%
sns.barplot(x=df['Pclass'],y=df['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x = df['Survived'], y = df['Age'], hue = df['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# # Density Graph ( Things we need to know for KDE Plot)

# %% [markdown]
# # Multivariate Analysis -4 ( KDE plot for categorical discrepancy )

# %%
sns.kdeplot(data = df, x = 'Age', hue = 'Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Multivariate Analysis -5 (Scatterplot)

# %%
df2 = sns.load_dataset('tips')

df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data = df2, x = 'total_bill', y = 'tip', hue = 'sex', size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Y Data Profiling

# %%
pip install ydata_profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 40.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title = 'Titanic Profile Report')

profile.to_file('My_Report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
