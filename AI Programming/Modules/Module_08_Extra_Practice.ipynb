# %% [markdown]
# <a href="https://colab.research.google.com/github/Abrar-404/AI-ML_Practices_and_Assignments/blob/main/Module_08_Extra_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice 1

# %%
import numpy as np

# %%
Celcius = np.array([0, 10, 20, 30, 40, 100])
Farenheit = Celcius * 1.8 + 32

print(Farenheit)
# Out:
# [ 32.  50.  68.  86. 104. 212.]

# %% [markdown]
# # Practice 2

# %%
lst = [72, 68, 75, 80, 69, 74, 71]

arr = np.array(lst)

print('Shape :', arr.shape)
print('Size :', arr.size)
print('Data Type :', arr.dtype)

new_arr = arr / 60
print(new_arr)
# Out:
# Shape : (7,)
# Size : 7
# Data Type : int64
# [1.2        1.13333333 1.25       1.33333333 1.15       1.23333333
#  1.18333333]
